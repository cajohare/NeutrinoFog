# %%
import sys
sys.path.append('../src')
from numpy import *
from numpy import random
import matplotlib as mpl
from mpl_toolkits.axes_grid1.inset_locator import (inset_axes, InsetPosition,mark_inset)
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from Like import *
from PlotFuncs import *
import cmocean
import NeutrinoFuncs
import WIMPFuncs

pek = line_background(6,'k')

fig,ax = MakeLimitPlot_SDp()

alph = 0.25

cols = cm.bone(linspace(0.3,0.9,5))


data = loadtxt('../data/WIMPLimits/mylimits/DLNuFloorF_detailed_SDp.txt')
m,sig,NUFLOOR,DY = Floor_2D(data,filt=True,filt_width=2,Ex_crit=1e10)
plt.plot(m,NUFLOOR,'-',color=cols[0,:],lw=3,label='Fluorine',path_effects=pek,zorder=1)
plt.fill_between(m,NUFLOOR,y2=1e-99,color=cols[0,:],zorder=1,alpha=0.5)

data = loadtxt('../data/WIMPLimits/mylimits/DLNuFloorNaI_detailed_SDp.txt')
m,sig,NUFLOOR,DY = Floor_2D(data,filt=True,filt_width=2,Ex_crit=1e10)
plt.plot(m,NUFLOOR,'-',color=cols[1,:],lw=3,label='NaI',path_effects=pek,zorder=0.5)
plt.fill_between(m,NUFLOOR,y2=1e-99,color=cols[1,:],zorder=0.5,alpha=0.5)


data = loadtxt('../data/WIMPLimits/mylimits/DLNuFloorXe_detailed_SDp.txt')
m,sig,NUFLOOR,DY = Floor_2D(data,filt=True,filt_width=2,Ex_crit=1e10)
plt.plot(m,NUFLOOR,'-',color=cols[2,:],lw=3,label='Xenon',path_effects=pek,zorder=0.1)
plt.fill_between(m,NUFLOOR,y2=1e-99,color=cols[2,:],zorder=0.1,alpha=0.5)


# data = loadtxt('../data/WIMPLimits/mylimits/DLNuFloorGe_detailed_SDp.txt')
# m,sig,NUFLOOR,DY = Floor_2D(data,filt=True,filt_width=2,Ex_crit=1e10)
# plt.plot(m,NUFLOOR,'-',color=cols[3,:],lw=3,label='Germanium',path_effects=pek,zorder=-1)
# plt.fill_between(m,NUFLOOR,y2=1e-99,color=cols[3,:],zorder=-1,alpha=0.5)


data = loadtxt('../data/WIMPLimits/mylimits/DLNuFloorSi_detailed_SDp.txt')
m,sig,NUFLOOR,DY = Floor_2D(data,filt=True,filt_width=2,Ex_crit=1e10)
plt.plot(m,NUFLOOR,'-',color=cols[4,:],lw=3,label='Si',path_effects=pek,zorder=-2)
plt.fill_between(m,NUFLOOR,y2=1e-99,color=cols[4,:],zorder=-2,alpha=0.5)


plt.text(0.12,0.2e-35,r'{\bf Silicon}',rotation=45,color='k')
#plt.text(0.12,3.5e-37,r'{\bf Ge}',rotation=40,color='k')
plt.text(0.12,5e-38,r'{\bf Xenon}',rotation=41,color='k')
plt.text(0.12,1e-40,r'{\bf NaI}',rotation=38,color='k')
plt.text(0.125,6e-43,r'{\bf Fluorine}',rotation=43,color='k')

#MySaveFig(fig,'NuFloor_Targets_SDp')
# Out:
# ../src/Like.py:68: RuntimeWarning: invalid value encountered in greater
#   Exmin = amin(Ex[Ex>0])
# ../src/Like.py:93: RuntimeWarning: invalid value encountered in less
#   DY[DY<2] = 2
# ../src/Like.py:68: RuntimeWarning: invalid value encountered in greater
#   Exmin = amin(Ex[Ex>0])
# ../src/Like.py:93: RuntimeWarning: invalid value encountered in less
#   DY[DY<2] = 2
# ../src/Like.py:68: RuntimeWarning: invalid value encountered in greater
#   Exmin = amin(Ex[Ex>0])
# ../src/Like.py:93: RuntimeWarning: invalid value encountered in less
#   DY[DY<2] = 2
# ../src/Like.py:68: RuntimeWarning: invalid value encountered in greater
#   Exmin = amin(Ex[Ex>0])
# ../src/Like.py:93: RuntimeWarning: invalid value encountered in less
#   DY[DY<2] = 2
# Text(0.125, 6e-43, '{\\bf Fluorine}')

# %%
pek = line_background(6,'k')
cmap = cm.terrain_r

fig,ax = MakeLimitPlot_SDp(Collected=True,alph=1,edgecolor=col_alpha('gray',0.75),facecolor=col_alpha('gray',0.5))

data = loadtxt('../data/WIMPLimits/mylimits/DLNuFloorXe_detailed_SDp.txt')
m,sig,NUFLOOR,DY = Floor_2D(data,filt=True,filt_width=2,Ex_crit=1e10)
cnt = plt.contourf(m,sig,DY,levels=linspace(2,15,100),vmax=6,vmin=2.2,cmap=cmap)
for c in cnt.collections:
    c.set_edgecolor("face")
plt.plot(m,NUFLOOR,'-',color='brown',lw=3,path_effects=pek,zorder=100)

im = plt.pcolormesh(-m,sig,DY,vmax=6,vmin=2.2,cmap=cmap,rasterized=True)
cbar(im,extend='min')
plt.gcf().text(0.82,0.9,r'$\left(\frac{{\rm d}\ln\sigma}{{\rm d}\ln N}\right)^{-1}$',fontsize=35)

plt.gcf().text(0.15*(1-0.01),0.16*(1+0.01),r'{\bf Xenon}',color='k',fontsize=50,alpha=0.2)
plt.gcf().text(0.15,0.16,r'{\bf Xenon}',color='brown',fontsize=50)

#MySaveFig(fig,'NuFloorDetailed_SDp_Xe')
# Out:
# ../src/Like.py:68: RuntimeWarning: invalid value encountered in greater
#   Exmin = amin(Ex[Ex>0])
# ../src/Like.py:93: RuntimeWarning: invalid value encountered in less
#   DY[DY<2] = 2
# Text(0.15, 0.16, '{\\bf Xenon}')

# %%
fig,ax = MakeLimitPlot_SDp(Collected=True,alph=1,edgecolor=col_alpha('gray',0.75),facecolor=col_alpha('gray',0.5))

data = loadtxt('../data/WIMPLimits/mylimits/DLNuFloorGe_detailed_SDp.txt')
m,sig,NUFLOOR,DY = Floor_2D(data,filt=True,filt_width=2,Ex_crit=1e10)
cnt = plt.contourf(m,sig,DY,levels=linspace(2,15,100),vmax=6,vmin=2.2,cmap=cmap)
for c in cnt.collections:
    c.set_edgecolor("face")
plt.plot(m,NUFLOOR,'-',color='brown',lw=3,path_effects=pek,zorder=100)


im = plt.pcolormesh(-m,sig,DY,vmax=6,vmin=2.2,cmap=cmap,rasterized=True)
cbar(im,extend='min')
plt.gcf().text(0.82,0.9,r'$\left(\frac{{\rm d}\ln\sigma}{{\rm d}\ln N}\right)^{-1}$',fontsize=35)

plt.gcf().text(0.15*(1-0.01),0.16*(1+0.01),r'{\bf Germanium}',color='k',fontsize=50,alpha=0.2)
plt.gcf().text(0.15,0.16,r'{\bf Germanium}',color='brown',fontsize=50)

#MySaveFig(fig,'NuFloorDetailed_SDp_Ge')
# Out:
# ../src/Like.py:68: RuntimeWarning: invalid value encountered in greater
#   Exmin = amin(Ex[Ex>0])
# ../src/Like.py:93: RuntimeWarning: invalid value encountered in less
#   DY[DY<2] = 2
# Text(0.15, 0.16, '{\\bf Germanium}')

# %%
fig,ax = MakeLimitPlot_SDp(Collected=True,alph=1,edgecolor=col_alpha('gray',0.75),facecolor=col_alpha('gray',0.5))

data = loadtxt('../data/WIMPLimits/mylimits/DLNuFloorF_detailed_SDp.txt')
m,sig,NUFLOOR,DY = Floor_2D(data,filt=True,filt_width=2,Ex_crit=1e11)
cnt = plt.contourf(m,sig,DY,levels=linspace(2,15,100),vmax=6,vmin=2.2,cmap=cmap)
for c in cnt.collections:
    c.set_edgecolor("face")
plt.plot(m,NUFLOOR,'-',color='brown',lw=3,path_effects=pek,zorder=100)

im = plt.pcolormesh(-m,sig,DY,vmax=6,vmin=2.2,cmap=cmap,rasterized=True)
cbar(im,extend='min')
plt.gcf().text(0.82,0.9,r'$\left(\frac{{\rm d}\ln\sigma}{{\rm d}\ln N}\right)^{-1}$',fontsize=35)

plt.gcf().text(0.15*(1-0.01),0.16*(1+0.01),r'{\bf Fluorine}',color='k',fontsize=50,alpha=0.2)
plt.gcf().text(0.15,0.16,r'{\bf Fluorine}',color='brown',fontsize=50,zorder=1)

#MySaveFig(fig,'NuFloorDetailed_SDp_F')
# Out:
# ../src/Like.py:68: RuntimeWarning: invalid value encountered in greater
#   Exmin = amin(Ex[Ex>0])
# ../src/Like.py:93: RuntimeWarning: invalid value encountered in less
#   DY[DY<2] = 2
# Text(0.15, 0.16, '{\\bf Fluorine}')

# %%
fig,ax = MakeLimitPlot_SDp(Collected=True,alph=1,edgecolor=col_alpha('gray',0.75),facecolor=col_alpha('gray',0.5))

data = loadtxt('../data/WIMPLimits/mylimits/DLNuFloorSi_detailed_SDp.txt')
m,sig,NUFLOOR,DY = Floor_2D(data,filt=True,filt_width=2,Ex_crit=1e11)
cnt = plt.contourf(m,sig,DY,levels=linspace(2,15,100),vmax=6,vmin=2.2,cmap=cmap)
for c in cnt.collections:
    c.set_edgecolor("face")
plt.plot(m,NUFLOOR,'-',color='brown',lw=3,path_effects=pek,zorder=100)

plt.gcf().text(0.82,0.9,r'$\left(\frac{{\rm d}\ln\sigma}{{\rm d}\ln N}\right)^{-1}$',fontsize=35,color='w')
plt.gcf().text(0.15*(1-0.01),0.16*(1+0.01),r'{\bf Silicon}',color='k',fontsize=50,alpha=0.2)
plt.gcf().text(0.15,0.16,r'{\bf Silicon}',color='brown',fontsize=50)

#MySaveFig(fig,'NuFloorDetailed_SDp_Si')
# Out:
# ../src/Like.py:68: RuntimeWarning: invalid value encountered in greater
#   Exmin = amin(Ex[Ex>0])
# ../src/Like.py:93: RuntimeWarning: invalid value encountered in less
#   DY[DY<2] = 2
# Text(0.15, 0.16, '{\\bf Silicon}')

# %%
fig,ax = MakeLimitPlot_SDp(Collected=True,alph=1,edgecolor=col_alpha('gray',0.75),facecolor=col_alpha('gray',0.5))

data = loadtxt('../data/WIMPLimits/mylimits/DLNuFloorNaI_detailed_SDp.txt')
m,sig,NUFLOOR,DY = Floor_2D(data,filt=True,filt_width=1,Ex_crit=1e10)
cnt = plt.contourf(m,sig,DY,levels=linspace(2,15,100),vmax=6,vmin=2.2,cmap=cmap)
for c in cnt.collections:
    c.set_edgecolor("face")
plt.plot(m,NUFLOOR,'-',color='brown',lw=3,path_effects=pek,zorder=100)

im = plt.pcolormesh(-m,sig,DY,vmax=6,vmin=2.2,cmap=cmap,rasterized=True)
cbar(im,extend='min')
plt.gcf().text(0.82,0.9,r'$\left(\frac{{\rm d}\ln\sigma}{{\rm d}\ln N}\right)^{-1}$',fontsize=35)


plt.gcf().text(0.15*(1-0.01),0.16*(1+0.01),r'{\bf NaI}',color='k',fontsize=50,alpha=0.2)
plt.gcf().text(0.15,0.16,r'{\bf NaI}',color='brown',fontsize=50)

#MySaveFig(fig,'NuFloorDetailed_SDp_NaI')
# Out:
# ../src/Like.py:68: RuntimeWarning: invalid value encountered in greater
#   Exmin = amin(Ex[Ex>0])
# ../src/Like.py:93: RuntimeWarning: invalid value encountered in less
#   DY[DY<2] = 2
# Text(0.15, 0.16, '{\\bf NaI}')

# %%
dat1 = loadtxt("../data/WIMPLimits/SDp/PICASSO.txt")
dat2 = loadtxt("../data/WIMPLimits/SDp/PICO60.txt")
dats = [dat1,dat2]

mmin = amin(dat1[:,0])
mmax = 1e4
mvals = logspace(log10(mmin),log10(mmax),1000)

sig = zeros(shape=1000)
for dat in dats:
    sig1 = 10**interp(log10(mvals),log10(dat[:,0]),log10(dat[:,1]))
    sig1[mvals<amin(dat[:,0])] = inf
    sig1[mvals>amax(dat[:,0])] = inf
    sig = column_stack((sig,sig1))
sig = sig[:,1:]

sig = amin(sig,1)

plt.loglog(mvals,sig,color='r',alpha=1,zorder=0.5,lw=2)

savetxt('../data/WIMPLimits/SDp/AllLimits-2021.txt',column_stack((mvals,sig)))
